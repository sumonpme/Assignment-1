# %%
# LogarithmicPlot.py
import matplotlib.pyplot as plt
import numpy as np

x = np.logspace(2, 10, 50)
y = np.log(x)

plt.plot(x, y)
plt.xscale('log')
plt.title('Logarithmic Plot')
plt.xlabel('Log X-axis')
plt.ylabel('Log of X')
plt.show()
