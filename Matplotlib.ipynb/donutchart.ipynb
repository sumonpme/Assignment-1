# %%
# DonutChart.py
import matplotlib.pyplot as plt

sizes = [25, 35, 20, 20]
labels = ['A', 'B', 'C', 'D']

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=120, wedgeprops=dict(width=0.5))
plt.title('Donut Chart')
plt.show()
