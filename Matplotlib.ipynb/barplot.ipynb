# %%
# BarPlot.py
import matplotlib.pyplot as plt

Countries = ['America', 'Brazil', 'China', 'Denmark']
values = [15, 10, 12, 16]

plt.bar(Countries, values, color='green')
plt.title('Bar Plot Example')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.legend('small in corner')
plt.show()
