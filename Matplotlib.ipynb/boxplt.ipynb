# %%
# BoxPlot.py
import matplotlib.pyplot as plt
import numpy as np
data = [np.random.normal(loc=mean, scale=1.0, size=100) for mean in [0, 5, 10]]
plt.boxplot(data, patch_artist=True, notch=True)
plt.title('Box Plot Example')
plt.xlabel('Group')
plt.ylabel('Values')
plt.show()
