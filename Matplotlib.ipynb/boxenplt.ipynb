# %%
# BoxenPlot.py
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data = np.random.exponential(scale=5.0, size=10000)
plt.figure(figsize=(8, 7))
sns.boxenplot(x=data)
plt.title('Boxen Plot Example')
plt.xlabel('Values')

plt.show()
