# %% [markdown]
# <a href="https://colab.research.google.com/github/sumonpme/Assignment-1/blob/main/latex_cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
\documentclass[10pt, letterpaper]{article}

% Packages:
\usepackage[
    ignoreheadfoot, % set margins without considering header and footer
    top=1.5 cm, % seperation between body and page edge from the top
    bottom=1.5 cm, % seperation between body and page edge from the bottom
    left=1.5 cm, % seperation between body and page edge from the left
    right=1.5 cm, % seperation between body and page edge from the right
    footskip=1.0 cm, % seperation between body and footer
    % showframe % for debugging
]{geometry} % for adjusting page geometry
\usepackage[explicit]{titlesec} % for customizing section titles
\usepackage{tabularx} % for making tables with fixed width columns
\usepackage{array} % tabularx requires this
\usepackage[dvipsnames]{xcolor} % for coloring text
\definecolor{primaryColor}{black}{0, 79, 144} % define primary color
\usepackage{enumitem} % for customizing lists
\usepackage{fontawesome5} % for using icons
\usepackage{amsmath} % for math
\usepackage[
    pdftitle={Sumon Ahmed's CV},
    pdfauthor={Sumon Ahmed},
    pdfcreator={LaTeX with Sumon CV},
    colorlinks=true,
    urlcolor=primaryColor
]{hyperref} % for links, metadata and bookmarks
\usepackage[pscoord]{eso-pic} % for floating text on the page
\usepackage{calc} % for calculating lengths
\usepackage{bookmark} % for bookmarks
\usepackage{lastpage} % for getting the total number of pages
\usepackage{changepage} % for one column entries (adjustwidth environment)
\usepackage{paracol} % for two and three column entries
\usepackage{ifthen} % for conditional statements
\usepackage{needspace} % for avoiding page brake right after the section title
\usepackage{iftex} % check if engine is pdflatex, xetex or luatex

% Ensure that generate pdf is machine readable/ATS parsable:
\ifPDFTeX
    \input{glyphtounicode}
    \pdfgentounicode=1
    \usepackage[T1]{fontenc}
    \usepackage[utf8]{inputenc}
    \usepackage{lmodern}
\fi

\usepackage[default, type1]{sourcesanspro}

% Some settings:
\AtBeginEnvironment{adjustwidth}{\partopsep0pt} % remove space before adjustwidth environment
\pagestyle{empty} % no header or footer
\setcounter{secnumdepth}{0} % no section numbering
\setlength{\parindent}{0pt} % no indentation
\setlength{\topskip}{0pt} % no top skip
\setlength{\columnsep}{0.15cm} % set column seperation
\makeatletter
\let\ps@customFooterStyle\ps@plain % Copy the plain style to customFooterStyle
\patchcmd{\ps@customFooterStyle}{\thepage}{
    \color{gray}\textit{\small page \thepage{} of \pageref*{LastPage}}
}{}{} % replace number by desired string
\makeatother
\pagestyle{customFooterStyle}

\titleformat{\section}{
    % avoid page braking right after the section title
    \needspace{4\baselineskip}
    % make the font size of the section title large and color it with the primary color
    \Large\color{primaryColor}
}{
}{
}{
    % print bold title, give 0.15 cm space and draw a line of 0.8 pt thickness
    % from the end of the title to the end of the body
    \textbf{#1}\hspace{0.15cm}\titlerule[0.8pt]\hspace{-0.1cm}
}[] % section title formatting

\titlespacing{\section}{
    % left space:
    -1pt
}{
    % top space:
    0.2 cm
}{
    % bottom space:
    0.2 cm
} % section title spacing

% \renewcommand\labelitemi{$\vcenter{\hbox{\small$\bullet$}}$} % custom bullet points
\newenvironment{highlights}{
    \begin{itemize}[
        topsep=0.10 cm,
        parsep=0.10 cm,
        partopsep=0pt,
        itemsep=0pt,
        leftmargin=0.3 cm + 10pt
    ]
}{
    \end{itemize}
} % new environment for highlights

\newenvironment{highlightsforbulletentries}{
    \begin{itemize}[
        topsep=0.10 cm,
        parsep=0.10 cm,
        partopsep=0pt,
        itemsep=0pt,
        leftmargin=10pt
    ]
}{
    \end{itemize}
} % new environment for highlights for bullet entries


\newenvironment{onecolentry}{
    \begin{adjustwidth}{
        0.2 cm + 0.00001 cm
    }{
        0.2 cm + 0.00001 cm
    }
}{
    \end{adjustwidth}
} % new environment for one column entries

\newenvironment{twocolentry}[2][]{
    \onecolentry
    \def\secondColumn{#2}
    \setcolumnwidth{\fill, 4.5 cm}
    \begin{paracol}{2}
}{
    \switchcolumn \raggedleft \secondColumn
    \end{paracol}
    \endonecolentry
} % new environment for two column entries

\newenvironment{threecolentry}[3][]{
    \onecolentry
    \def\thirdColumn{#3}
    \setcolumnwidth{1 cm, \fill, 4.5 cm}
    \begin{paracol}{3}
    {\raggedright #2} \switchcolumn
}{
    \switchcolumn \raggedleft \thirdColumn
    \end{paracol}
    \endonecolentry
} % new environment for three column entries

\newenvironment{header}{
    \setlength{\topsep}{0pt}\par\kern\topsep\centering\color{primaryColor}\linespread{1.5}
}{
    \par\kern\topsep
} % new environment for the header

\newcommand{\placelastupdatedtext}{% \placetextbox{<horizontal pos>}{<vertical pos>}{<stuff>}
  \AddToShipoutPictureFG*{% Add <stuff> to current page foreground
    \put(
        \LenToUnit{\paperwidth-2 cm-0.2 cm+0.05cm},
        \LenToUnit{\paperheight-1.0 cm}
    ){\vtop{{\null}\makebox[0pt][c]{
        \small\color{gray}{September 6, 2025}}\hspace{\widthof{{September 6, 2025}}
    }}}%
  }%
}%

% save the original href command in a new command:
\let\hrefWithoutArrow\href

% new command for external links:
\renewcommand{\href}[2]{\hrefWithoutArrow{#1}{\ifthenelse{\equal{#2}{}}{ }{#2 }\raisebox{.15ex}{\footnotesize \faExternalLink*}}}


\begin{document}
    \newcommand{\AND}{\unskip
        \cleaders\copy\ANDbox\hskip\wd\ANDbox
        \ignorespaces
    }
    \newsavebox\ANDbox
    \sbox\ANDbox{}

    \placelastupdatedtext
    \begin{header}
        \fontsize{24 pt}{24 pt}
        \textbf{Sumon Ahmed}

        \vspace{0.3 cm}

        \normalsize
        \mbox{{\footnotesize\faMapMarker*}\hspace*{0.13cm} Dresdnerstrasse 4, 09599, Freiberg, Deutschland}%
        \kern 0.25 cm%
        \AND%
        \kern 0.25 cm%
        \mbox{\hrefWithoutArrow{mailto:sumonjust14@gmail.com}{{\footnotesize\faEnvelope[regular]}\hspace*{0.13cm}sumonjust14@gmail.com}}%
        \kern 0.25 cm%
        \AND%
        \kern 0.25 cm%
        \mbox{\hrefWithoutArrow{tel:+4917646539977}{{\footnotesize\faPhone*}\hspace*{0.13cm}+4917646539977}}%
        \kern 0.25 cm%

        \AND%
        \kern 0.25 cm%
        \mbox{\hrefWithoutArrow{https://linkedin.com/in/sumon-ahmed-30aa2929b/}{{\footnotesize\faLinkedinIn}\hspace*{0.13cm}sumon-ahmed-30aa2929b}}%
        \kern 0.25 cm%
           \end{header}

    \vspace{0.2 cm - 0.2 cm}


    \section{Persönliches Profil}

     Ich bin Masterabsolvent im Studiengang Sustainable Mining and Remediation Management an der TU Bergakademie Freiberg sowie Bachelorabsolvent in Petroleum and Mining Engineering. Mein fachliches Interesse liegt in der nachhaltigen Nutzung geologischer Ressourcen sowie in der Weiterentwicklung moderner Technologien im Bergbau. Durch mein Studium und meine praktischen Erfahrungen verfüge ich über fundierte Kenntnisse in Lagerstättenkunde, Rohstoffgewinnung, Geowissenschaften, Umwelttechnik, der Mineralienverarbeitung zu sammeln und Bergbausanierung. Ich möchte mein Wissen in praxisorientierten und forschungsbezogenen Projekten einsetzen und innovative Lösungen für eine zukunftsfähige Rohstoffindustrie mitgestalten.

         \vspace{0.2 cm}

    \section{Berufserfahrungen}


    \begin{twocolentry} {\textit{Freiberg, Deutschland}

        \textit{Jul. 2025 -- aktuell}}

            \textbf{ERZLABOR Advanced Solutions GmbH}

            {Wissenschaftlicher Mitarbeiter}
    \begin{itemize}
           \item \mbox{Entnahme von Rohproben, Mahlen, Zerkleinern, Aufspalten, Flotation, XRF und Datenanalyse.}

    \end{itemize}
           \end{twocolentry}
        \vspace{0.2 cm}

    \begin{twocolentry} {\textit{Freiberg, Deutschland}


        \textit{Dec 2024 – Aug 2025}
        }
            \textbf{Helmholtz-Institut Freiberg für Ressourcentechnologie (HIF) at HZDR}

            {Masterarbeit}

    \mbox {Das Thema meiner Masterarbeit lautet „Gewinnung von Kassiterit aus alten Bergbauabfällen: Verbesserte Wiederaufbereitung}
    \mbox {durch Online-Prozessüberwachung“. Meine Arbeit konzentriert sich auf die Flotation von Kassiterit aus Bergbauabfällen,}  {einschließlich - }

    \begin{itemize}
                \item mineralogischer Charakterisierung (XRD, XRF, PSD).
                \item \mbox {Kollektorevaluierung und Prozessoptimierung unter Verwendung von Central Composite Design}.
                \item \mbox {Durchführung einer vergleichenden Analyse unter Verwendung mechanischer und pneumatischer Flotationszellen}.
                \item \mbox {Kalibrierung und Analyse von Daten aus pXRF,
                 microXRF und R-XRF sowie Anwendung von R-Programmierung für die}
                 {Prozessmodellierung}.
                 \item statistische Analyse.
                 \item Optimierung und Datenanalyse.

            \end{itemize}
        \end{twocolentry}


        \vspace{0.2 cm}

        \begin{twocolentry}{ \textit{Freiberg, Deutschland}


        \textit{Jun 2024 – Jul 2024}
        }
            \textbf{Institut für Bergbau und Spezialtiefbau,TU Bergakademie Freiberg}

            {Wissenschaftlicher Mitarbeiter}
            \begin{itemize}
                \item Aufsicht über das Radioaktivitätspraktikum
                \item Bewertung des Praktikumsberichts
                \item Bewertung der Hausarbeit zur Radioaktivitätsvorlesung
                \item Aktualisierung der Informationen zur Radioaktivitätsvorlesung.

            \end{itemize}
        \end{twocolentry}
        \vspace{0.2 cm}

        \begin{twocolentry}{ \textit{KUSHTIA, BANGLADESCH}


        \textit{Jan 2020 – Dec 2020}
        }
            \textbf{DAULATPUR IT CENTER}

            {IT -SUPPORT -SPECIALIST}
            \begin{itemize}
                \item Installation und Konfiguration von Computerhardware, Software, Druckern undScannern.
                \item Überwachung und Wartung von Computersystemen und netzen.
                \item Reparieren und Ersetzen von Geräten nach Bedarf.
                \item Unterstützung bei der Fehlerbehebung bei Druckern
                \item Unterstützung bei der Einarbeitung neuer Benutzer.

            \end{itemize}
        \end{twocolentry}
        \vspace{0.2 cm}

        \begin{twocolentry}{ \textit{Jashore, BANGLADESCH}


        \textit{Aug 2018 – Jun 2019}
        }
            \textbf{CLEAN ENERGY AND CARBON CAPTURE LAB, JASHORE UNIVERSITY OF SCIENCE AND TECHNOLOGY}

            {Wissenschaftlicher Mitarbeiter}
            \begin{itemize}
                \item \mbox{Sammlung von Motherboards und Lithium-Ionen Altbatterien,Demontage ,Anoden und Kathodentrennung
                ,Entladung und}
                {Auflösung ,Geräteaufbau ,Datenrecherche und analyse.}
            \end{itemize}
        \end{twocolentry}
        \vspace{0.2 cm}

        \begin{twocolentry}{ \textit{Joypurhat, BANGLADESCH}


        \textit{Dec 2018 – Dec 2018}
        }
            \textbf{INSTITUTE OF MINING, MINERALOGY AND METALLURGY(IMMM) BCSIR}

            {PRAKTIKUM }
            \begin{itemize}
                \item \mbox{Feldbesichtigung, Probenahme, Vorbereitung für die Analyse, Chemikalien, Mischen, Beobachtung der Instrumente,XRF}.

            \end{itemize}
        \end{twocolentry}
        \vspace{0.2 cm}



    \section{Allgemeine und Berufliche Bildung}




        \begin{twocolentry} {\textit {Freiberg, Deutschland}


           \textit Apr 2021 – Aug 2025
        }
            \textbf{TECHNISCHE UNIVERSITÄT BERGAKADEMIE FREIBERG }

            {M.Sc in Nachhaltiges Bergbau‑ und Sanierungsmanagement}
            \begin{itemize}
                \item \mbox{Module: Lagerstätten und Wirtschaftsgeologie, Grundwasserchemie, Projektmanagement, Bergwasser, Hydrologie und}
                \mbox {Modellierung, Chemie und Mineralanalyse, Biotechnologie, Sanierung, Revitalisierung von Altlasten, Radioaktivität, Projekt }
                 {und Kontakt management, Usw}
                \item \mbox {Labor: Hydrogeologie und Modellierung, Bergwasserchemie und ‑behandlung, Grundwasserchemie, Biotechnologie,}
                {Radioaktivität}.
            \end{itemize}
        \end{twocolentry}
        \vspace{0.2 cm}

         \begin{twocolentry} {\textit {Jashore, Bangladesch}


           \textit Jan 2015 – Jun 2019
        }
            \textbf{Jashore University of Science and Technology  }

            {B.Sc(Ing.) in  in Erdöl‑ und Bergbau Ingenieurwesen }
            \begin{itemize}
                \item \mbox{Module: Geologie, Tagebau‑System, Untertage‑Bergbausystem, Minenplanung und design, Minenuntersuchung, Geoinformatik,}
                \mbox {Geotechnik,Geochemie, Geophysik, Boden‑ und Felsmechanik, Hydrologie, Entwässerung, Mineral verarbeitung, Reservoir-}
                {gestein, Reservoirtechnik, Usw}
                \item \mbox {Labor: GIS, Geologie, Hydrologie, GW, Geotechnische, Geochemie, Mineral verarbeitung, Vermessung, Maschinen und}
                {Wartungslabor}.

            \end{itemize}
        \end{twocolentry}



    \section{Universitätsprojekte }


        \begin{twocolentry}{ \textit{Jashore, BANGLADESCH}


        \textit{Sep 2018 – June 2019}
        }
            \textbf{Bachelorarbeit: "Gewinnung von Lithium und Kobalt aus gebrauchten Lithium-Ionen- Batterien". }

            {Jashore University of Science and Technology  }
            \begin{itemize}
                \item \mbox{Biohydrometallurgische Prozesse ,Fällung ,Biolaugung ,Chemische Auflösung und Anpassung ,PH-Wert Einstellung,Datenanalyse}.

            \end{itemize}
        \end{twocolentry}




    \section{Sprachkenntnisse}


         \begin{onecolentry}
            \textbf{Englisch:} {C1}

            \textbf{Deutsch:} {B1}

            \textbf{Bengalisch:} {Nativ}
        \end{onecolentry}

        \vspace{0.2 cm}


    \section{Kenntnisse & Fähigkeiten }


         \begin{onecolentry}
            \textbf {Software & Tools : }{Microsoft Excel, Python, Microsoft Powerpoint, Microsoft Word, Machine Learing, Github, R Programmimg,Arc GIS, Q GIS, Remote Sensing, Google Earth Engine (GEE) / Google Earth Pro, Google IT support, MLA Data
            View}.

        \textbf{Methodische Kompetenzen : } {Zeitmanagement, Projektmanagement, Teamarbeit, Problemlösungsfähigkeit. }.

            \textbf{Fachliche Kompetenzen : } {XRF, XRD, Data Analysis, Mineral processing, Flotation, Mineral characterization, Recycling, }

        \end{onecolentry}

        \vspace{0.2 cm}


    \section{Forschungsinteressen }

    \item  Mineralaufbereitung, Mineralcharakterisierung, Flotation, Verfahrenstechnik, Explorationsgeologie, GIS, Recycling
 Abfallstoffe.


\section{Geowissenschaftliche und Bergbauprojekte (Teamarbeit)}


        \begin{twocolentry}{  \textit{Oct 2021 – Mar 2022}
        }
            \textbf{PROJEKT‑ UND KONTAKT MANAGEMENT  }

            \begin{itemize}
                \item \mbox{Erfolgreich die Umstellung von Tagebau auf Untertagebau durch strategische Projektplanung und Maschinen auswahl verwaltet }.
                \item \mbox {Effektive Kontakt management strategien, um die Kommunikation und Zusammen arbeit mit den Projekt beteiligten zu optimieren}.

            \end{itemize}
        \end{twocolentry}
         \vspace{0.2 cm}

         \begin{twocolentry}{  \textit{Oct 2021 – Mar 2022}
        }
            \textbf{MANAGEMENT UND FINANZIERUNG VON BERGBAU OPERATIONEN ENTLANG DES LEBENSZYKLUS  }

            \begin{itemize}
                \item \mbox{Erfolgreich Budgets verwaltet und Bergbau projekte geplant, um die Einhaltung finanzieller Ziele und Vorgaben sicherzustellen}.
                \item \mbox {Habe AHP‑Methoden angewendet, um Entscheidungs findung und wirtschaftliche Projekt evaluation durch zuführen }.
                \item \mbox {Projektfähigkeiten: AHP, Projekt Management, Projekt Planung, Stakeholder‑Management, Finanzanalyse Planung}
                {und Modellierung}.

            \end{itemize}
        \end{twocolentry}
         \vspace{0.2 cm}


        \begin{twocolentry}{  \textit{Apr 2022 – Sep 2022}
        }
            \textbf{LIZENZIERUNG, STAKEHOLDER‑BETEILIGUNG UND ERWARTUNGS MANAGEMENT  }

            \begin{itemize}
                \item \mbox{Analysierte die Bedürfnisse und Erwartungen der Stakeholder und passte Kommunikationsstrategien an}.
                \item \mbox {Bewertete die Wirksamkeit der Einbindung der Stakeholder anhand von Rückmeldungen und Metriken }.

            \end{itemize}
        \end{twocolentry}







    \section{Interessen}

        \begin{onecolentry}
            \textbf{Sport & Fitness:}  Ich begeistere mich für Cricket, Fußball sowie Fitnesstraining im Studio.

         \textbf {Lesen:} Ich habe interesse an Sachbüchern, insbesondere in den Bereichen Geologie, Umwelt und Technologie

         \textbf {Reisen:}  Ich bin Leidenschaft für das Reisen und das Kennenlernen neuer Kulturen }
        \end{onecolentry}

        \vspace{0.2 cm}


    \section{Referenz }

        Dr. Martin Rudolph, Leiter der Abteilung Verarbeitung, Helmholtz-Institut Freiberg für Ressourcentechnologie (HIF).

        Handy: +49 (0) 351 260 4410


        Email: m.rudolph@hzdr.de

          \vspace{0.3 cm}

     Dr. Duong Huu Hoang, Wissenschaftlicher Mitarbeiter, Abteilung Mineralverarbeitung, Helmholtz-Institut Freiberg für Ressourcentechnologie (HIF).

        Handy: +491737308112


        Email: d.hoang@hzdr.de

        Betreuer der Masterarbeit



\end{document}
